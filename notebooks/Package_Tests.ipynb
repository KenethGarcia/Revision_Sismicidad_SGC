# %% [markdown]
# # Package Tests
#
# This notebook will make some tests to check if the package is working correctly. We will start by doing some simple TOML files to check if the package is able to read them correctly. Then we will move on to more complex tests.
#
# To initialize any object in the package, you will need to create a TOML file with the configuration of the object you want to create. The package will read this file and create the object accordingly.

# %%
from src.core import runner as pyrsnc

runner_obj = pyrsnc.Runner(config_path="test.toml")

# %% [markdown]
# At the initialization of the Runner object, the package will read the TOML file and create the object accordingly. If the TOML file is not found or is not valid, the package will raise an error. Let's start with a simple TOML file to check if the package is able to read it correctly. The TOML file will contain the configuration of a simple object that we will create.
#
# Any TOML file must have at least the following info:
# - A database provided
# - A query to be executed on the database
#
# ```toml
# [[database]]
# name       = "sc6"
# env_file   = ".env"  # It requires the .env file at the same path as the TOML file, otherwise specify the full path to the .env file
# env_prefix = "SERVER_SC6"
#
# [[queries]]
# name       = "sc6"
# sql_file   = "./queries/revision.sql"
# description= "Query to retrieve events from SeisComP6 database"
# database   = "sc6"
# ```

# %%
print(runner_obj.list_queries())
# Out:
# ['SeisComP3', 'SeisComP6']

# %%
result = runner_obj.run()

# %%
result.total_events
# Out:
#                     time_value       publicID  depth_value  magnitude_value  \
# 0    2026-01-03 12:50:36+00:00  SGC2026aeqzwf   139.960938         4.138011
# 1    2026-01-03 18:02:57+00:00  SGC2026afbizi    37.070312         2.927446
# 2    2026-01-03 18:57:35+00:00  SGC2026afdebv    23.400000         0.856006
# 3    2026-01-03 21:22:20+00:00  SGC2026afhyui    60.550000         1.535298
# 4    2026-01-03 22:22:32+00:00  SGC2026afjytm   139.492188         2.878409
# ...                        ...            ...          ...              ...
# 2559 2026-04-01 11:33:34+00:00  SGC2026gkcixf    53.796317         2.301955
# 2560 2026-04-01 11:45:33+00:00  SGC2026gkctfd    10.000000         0.324661
# 2561 2026-04-01 11:51:58+00:00  SGC2026gkcysx    10.000000         1.144346
# 2562 2026-04-01 11:53:44+00:00  SGC2026gkdagl   130.612723         1.935232
# 2563 2026-04-01 11:55:42+00:00  SGC2026gkdbyo    10.000000        -0.779102
#
#       quality_standardError  depth_uncertainty  latitude_uncertainty  \
# 0                  1.317026           3.805547              2.401441
# 1                  1.382402           6.336486              3.090210
# 2                  0.670000           8.500000              5.656854
# 3                  0.140000          12.500000              3.818377
# 4                  1.290398           4.320529              2.712027
# ...                     ...                ...                   ...
# 2559               0.620182           4.148976              3.168776
# 2560               4.036632                NaN                   NaN
# 2561              12.148123                NaN                   NaN
# 2562               0.633822           9.200862              5.277715
# 2563               8.574671                NaN                   NaN
#
#       longitude_uncertainty  quality_associatedPhaseCount  \
# 0                  2.632750                         197.0
# 1                  3.722662                          72.0
# 2                  5.656854                          11.0
# 3                  3.818377                           7.0
# 4                  3.283069                         122.0
# ...                     ...                           ...
# 2559               2.831864                          24.0
# 2560                    NaN                           NaN
# 2561                    NaN                           NaN
# 2562               8.421233                          19.0
# 2563                    NaN                           NaN
#
#       quality_usedPhaseCount  ... quality_associatedStationCount  \
# 0                      176.0  ...                            NaN
# 1                       59.0  ...                            NaN
# 2                       11.0  ...                            NaN
# 3                        7.0  ...                            NaN
# 4                      111.0  ...                            NaN
# ...                      ...  ...                            ...
# 2559                    24.0  ...                            NaN
# 2560                     NaN  ...                            NaN
# 2561                     NaN  ...                            NaN
# 2562                    19.0  ...                            NaN
# 2563                     NaN  ...                            NaN
#
#          event_type  creationInfo_agencyID  \
# 0        earthquake                    SGC
# 1        earthquake                    SGC
# 2        earthquake                    SGC
# 3     not locatable                    SGC
# 4        earthquake                    SGC
# ...             ...                    ...
# 2559     earthquake                    SGC
# 2560  not locatable                    SGC
# 2561  not locatable                    SGC
# 2562     earthquake                    SGC
# 2563  not locatable                    SGC
#
#                                              text latitude_value  \
# 0                Villanueva - Santander, Colombia       6.714409
# 1                     Riosucio - ChocÃ³, Colombia       7.260504
# 2                  PulÃ­ - Cundinamarca, Colombia       4.723500
# 3            Puerto Wilches - Santander, Colombia       7.470667
# 4                Los Santos - Santander, Colombia       6.782142
# ...                                           ...            ...
# 2559         Ciudad Bolívar - Antioquia, Colombia       5.814218
# 2560                Dabeiba - Antioquia, Colombia       7.018000
# 2561                San Gil - Santander, Colombia       6.592000
# 2562             Los Santos - Santander, Colombia       6.828385
# 2563  La Esperanza - Norte de Santander, Colombia       7.705400
#
#      longitude_value  magnitude_type   methodID       earthModelID  \
# 0         -73.151004           MLr_3  NonLinLoc  Poveda_et_al_2018
# 1         -76.876872           MLr_1  NonLinLoc  Poveda_et_al_2018
# 2         -74.642167           MLr_2     Hypo71               RSNC
# 3         -73.859833         MLr_vmm     Hypo71               RSNC
# 4         -73.168157           MLr_3  NonLinLoc  Poveda_et_al_2018
# ...              ...             ...        ...                ...
# 2559      -75.944334           MLr_1  NonLinLoc  Poveda_et_al_2018
# 2560      -76.210000           MLr_1
# 2561      -73.182000           MLr_3
# 2562      -73.145575           MLr_3  NonLinLoc  Poveda_et_al_2018
# 2563      -73.334400         MLr_vmm
#
#            comment
# 0     b'DESTACADO'
# 1             None
# 2             None
# 3             None
# 4             None
# ...            ...
# 2559          None
# 2560          None
# 2561          None
# 2562          None
# 2563          None
#
# [2564 rows x 22 columns]

# %%
result.duplicates
# Out:
# Empty DataFrame
# Columns: [time_value, publicID, depth_value, magnitude_value, quality_standardError, depth_uncertainty, latitude_uncertainty, longitude_uncertainty, quality_associatedPhaseCount, quality_usedPhaseCount, creationInfo_author, quality_usedStationCount, quality_associatedStationCount, event_type, creationInfo_agencyID, text, latitude_value, longitude_value, magnitude_type, methodID, earthModelID, comment]
# Index: []
#
# [0 rows x 22 columns]

# %%
result.checks
# Out:
#                     time_value       publicID  depth_value  magnitude_value  \
# 4890 2026-08-31 15:00:28+00:00  SGC2026rdjoym     4.510000         2.565373
# 5086 2026-09-06 01:45:00+00:00  SGC2026rnjotn    95.496652         1.667690
#
#       quality_standardError  depth_uncertainty  latitude_uncertainty  \
# 4890               0.400000           2.700000              1.484924
# 5086               0.376446           8.438027              7.487553
#
#       longitude_uncertainty  quality_associatedPhaseCount  \
# 4890               1.484924                          18.0
# 5086               5.034114                          14.0
#
#       quality_usedPhaseCount  ...  event_type  creationInfo_agencyID  \
# 4890                    18.0  ...  earthquake                    SGC
# 5086                    14.0  ...  earthquake                    SGC
#
#                                          text latitude_value longitude_value  \
# 4890    Panamá - Colombia , Región Fronteriza       7.527167      -77.988167
# 5086  La Victoria - Valle del Cauca, Colombia       4.476449      -76.082018
#
#
#     longitude_uncertainty  quality_associatedPhaseCount  \
# 0                3.889087                          14.0
# 1                5.232590                          11.0
# 2                5.091169                          19.0
# 3                0.061900                           NaN
# 4                0.707107                          14.0
# 5                3.323402                           7.0
# 6                5.303301                          15.0
# 7                4.819145                          49.0
# 8                7.821433                          19.0
# 9                     NaN                           NaN
# 10               5.504258                         140.0
# 11               2.899138                          22.0
# 12               1.909188                          18.0
# 13               3.083073                          72.0
# 14               2.333452                          69.0
# 15               2.468013                         120.0
# 16               9.399577                          27.0
# 17               9.876757                          23.0
# 18                    NaN                           NaN
# 19              10.535891                           7.0
# 20               4.916613                          27.0
# 21                    NaN                          13.0
# 22               1.484924                          18.0
#
#     quality_usedPhaseCount  ...                   event_type  \
# 0                     14.0  ...                   earthquake
# 1                     11.0  ...                   earthquake
# 2                     19.0  ...                   earthquake
# 3                     57.0  ...  outside of network interest
# 4                     14.0  ...                   earthquake
# 5                      7.0  ...                    explosion
# 6                     13.0  ...                    explosion
# 7                     45.0  ...                   earthquake
# 8                     19.0  ...                   earthquake
# 9                      NaN  ...  outside of network interest
# 10                   125.0  ...  outside of network interest
# 11                    20.0  ...                   earthquake
# 12                    10.0  ...                   earthquake
# 13                    71.0  ...                   earthquake
# 14                    68.0  ...                   earthquake
# 15                   117.0  ...                   earthquake
# 16                    24.0  ...                   earthquake
# 17                    23.0  ...                   earthquake
# 18                    24.0  ...            volcanic eruption
# 19                     7.0  ...                   earthquake
# 20                    18.0  ...                   earthquake
# 21                    13.0  ...                   earthquake
# 22                    18.0  ...                   earthquake
#
#     creationInfo_agencyID                                               text  \
# 0                     SGC                       Onzaga - Santander, Colombia
# 1                     SGC      San Vicente de ChucurÃ­ - Santander, Colombia
# 2                     SGC                                    Océano Pacífico
# 3                    USGS                                      Puerto, Chile
# 4                     SGC                     Colombia-Ecuador Border Region
# 5                     SGC              La Jagua de Ibirico - Cesar, Colombia
# 6                     SGC                        Becerrill - Cesar, Colombia
# 7                     SGC                   Los Santos - Santander, Colombia
# 8                     SGC           Arboledas - Norte de Santander, Colombia
# 9                    USGS                                  Oistins, Barbados
# 10                    SGC                                   Windward Islands
# 11                    SGC                                    Océano Pacífico
# 12                    SGC  El Litoral del San Juán (Docordó) - Chocó, Col...
# 13                    SGC  El Litoral del San Juán (Docordó) - Chocó, Col...
# 14                    SGC                                    Océano Pacífico
# 15                    SGC                          Istmina - Chocó, Colombia
# 16                    SGC                             Sipí - Chocó, Colombia
# 17                    SGC                     Marsella - Risaralda, Colombia
# 18                 OVSPOP  Totoró - Cauca, Colombia - Área de Influencia ...
# 19                    SGC                      San Agustín - Huila, Colombia
# 20                    SGC                         El Tambo - Cauca, Colombia
# 21                   OVSP              Área de Influencia del Volcán Galeras
# 22                    SGC              Panamá - Colombia , Región Fronteriza
#
#    latitude_value longitude_value magnitude_type   methodID  \
# 0        6.221167      -72.782667          MLr_3     Hypo71
# 1        6.739833      -73.395000        MLr_vmm     Hypo71
# 2        2.555333      -79.800333          MLr_1     Hypo71
# 3      -20.032900      -70.950000            mwr
# 4        0.793667      -77.929500          MLr_1     Hypo71
# 5        9.643167      -73.413000          MLr_4     Hypo71
# 6        9.684000      -73.341333          MLr_4     Hypo71
# 7        6.791371      -73.110256          MLr_3  NonLinLoc
# 8        7.534811      -72.944324          MLr_3  NonLinLoc
# 9       11.900000      -59.100000             mb
# 10      12.124347      -59.531719        Mw(Mwp)     LOCSAT
# 11       5.852167      -78.327667          MLr_1     Hypo71
# 12       4.144667      -76.788333          MLr_1     Hypo71
# 13       4.120063      -76.769755          MLr_1  NonLinLoc
# 14       3.054667      -79.252167          MLr_1     Hypo71
# 15       4.464816      -76.705386          MLr_1  NonLinLoc
# 16       4.698529      -76.328161          MLr_1  NonLinLoc
# 17       4.924839      -75.764090          MLr_2  NonLinLoc
# 18       2.399000      -76.337333            MLr     Hypo71
# 19       2.100167      -76.529333          MLr_2     Hypo71
# 20       2.430138      -76.888878          MLr_1  NonLinLoc
# 21       1.290207      -77.415121            MLr
# 22       7.527167      -77.988167          MLr_1     Hypo71
#
#          earthModelID      comment  \
# 0                RSNC         None
# 1                 VMM         None
# 2                RSNC         None
# 3
# 4                RSNC         None
# 5         modelCesar2         None
# 6         modelCesar2         None
# 7   Poveda_et_al_2018         None
# 8   Poveda_et_al_2018         None
# 9                             None
# 10             iasp91         None
# 11               RSNC         None
# 12               RSNC         None
# 13  Poveda_et_al_2018         None
# 14               RSNC         None
# 15  Poveda_et_al_2018  DESTACADO\n
# 16  Poveda_et_al_2018         None
# 17  Poveda_et_al_2018         None
# 18               RSNC  DESTACADO\n
# 19               RSNC         None
# 20  Poveda_et_al_2018         None
# 21
# 22               RSNC         None
#
#                                         Observations
# 0    SSWA: Possible duplicate event of SGC2026evfjyn
# 1    SSWA: Possible duplicate event of SGC2026evfjqe
# 2                 Incorrect magnitude type for zone1
# 3        Event with comment different from DESTACADO
# 4                 Incorrect magnitude type for zone1
# 5    SSWA: Possible duplicate event of SGC2026iyqgwu
# 6    SSWA: Possible duplicate event of SGC2026iyqgvw
# 7    SSWA: Possible duplicate event of SGC2026jaxfag
# 8    SSWA: Possible duplicate event of SGC2026jaxezo
# 9    SSWA: Possible duplicate event of SGC2026kpdwsu
# 10  SSWA: Possible duplicate event of USGS2026gcdsqo
# 11                Incorrect magnitude type for zone1
# 12   SSWA: Possible duplicate event of SGC2026psdocc
# 13   SSWA: Possible duplicate event of SGC2026psdoen
# 14                Incorrect magnitude type for zone1
# 15       Event with comment different from DESTACADO
# 16   SSWA: Possible duplicate event of SGC2026qputel
# 17   SSWA: Possible duplicate event of SGC2026qputsi
# 18       Event with comment different from DESTACADO
# 19   SSWA: Possible duplicate event of SGC2026rauaxl
# 20   SSWA: Possible duplicate event of SGC2026rauaxm
# 21       Event with comment different from DESTACADO
# 22                Incorrect magnitude type for zone1
#
# [23 rows x 23 columns]

# %%
result = runner_obj.update_from_cache(events_df=result.total_events)

# %%
#result.duplicates

# %%
result.checks
# Out:
#                      time_value         publicID  depth_value  \
# 3820  2026-03-18 15:22:57+00:00    SGC2026fkrugu    41.310000
# 5024  2026-03-23 22:19:19+00:00  USGS_us7000s76i    14.520000
# 5699  2026-03-26 22:53:32+00:00    SGC2026fzynny     1.000000
# 25336 2026-06-18 09:27:40+00:00    SGC2026lxcvaw    20.000000
# 38253 2026-08-11 09:03:38+00:00    SGC2026psffvr     4.320000
# 39295 2026-08-14 13:08:08+00:00    SGC2026pyanec    45.248326
# 44199 2026-08-29 22:09:49+00:00   OVSPOP_2833568     9.000000
# 44514 2026-08-30 18:48:37+00:00      OVSP4910444    14.121221
# 44811 2026-08-31 15:00:28+00:00    SGC2026rdjoym     4.510000
#
#        magnitude_value  quality_standardError  depth_uncertainty  \
# 3820          2.821528                1.15000             0.0000
# 5024          4.600000                0.72000                NaN
# 5699          1.740561                0.37000             0.9000
# 25336         2.326374                1.24000             6.2000
# 38253         3.135464                1.17000             3.1000
# 39295         3.238456                1.06123             5.1513
# 44199         2.800000                0.11000                NaN
# 44514         2.200000                0.07000                NaN
# 44811         2.565373                0.40000             2.7000
#
#        latitude_uncertainty  longitude_uncertainty  \
# 3820               5.091169               5.091169
# 5024               0.039300               0.061900
# 5699               0.707107               0.707107
# 25336              2.899138               2.899138
# 38253              2.333452               2.333452
# 39295              2.164437               2.468013
# 44199                   NaN                    NaN
# 44514                   NaN                    NaN
# 44811              1.484924               1.484924
#
#        quality_associatedPhaseCount  quality_usedPhaseCount  ...  \
# 3820                           19.0                    19.0  ...
# 5024                            NaN                    57.0  ...
# 5699                           14.0                    14.0  ...
# 25336                          22.0                    20.0  ...
# 38253                          69.0                    68.0  ...
# 39295                         120.0                   117.0  ...
# 44199                           NaN                    24.0  ...
# 44514                          13.0                    13.0  ...
# 44811                          18.0                    18.0  ...
#
#                         event_type  creationInfo_agencyID  \
# 3820                    earthquake                    SGC
# 5024   outside of network interest                   USGS
# 5699                    earthquake                    SGC
# 25336                   earthquake                    SGC
# 38253                   earthquake                    SGC
# 39295                   earthquake                    SGC
# 44199            volcanic eruption                 OVSPOP
# 44514                   earthquake                   OVSP
# 44811                   earthquake                    SGC
#
#                                                     text latitude_value  \
# 3820                                     Océano Pacífico       2.555333
# 5024                                       Puerto, Chile     -20.032900
# 5699                      Colombia-Ecuador Border Region       0.793667
# 25336                                    Océano Pacífico       5.852167
# 38253                                    Océano Pacífico       3.054667
# 39295                          Istmina - Chocó, Colombia       4.464816
# 44199  Totoró - Cauca, Colombia - Área de Influencia ...       2.399000
# 44514              Área de Influencia del Volcán Galeras       1.290207
# 44811              Panamá - Colombia , Región Fronteriza       7.527167
#
#       longitude_value magnitude_type   methodID       earthModelID  \
# 3820       -79.800333          MLr_1     Hypo71               RSNC
# 5024       -70.950000            mwr
# 5699       -77.929500          MLr_1     Hypo71               RSNC
# 25336      -78.327667          MLr_1     Hypo71               RSNC
# 38253      -79.252167          MLr_1     Hypo71               RSNC
# 39295      -76.705386          MLr_1  NonLinLoc  Poveda_et_al_2018
# 44199      -76.337333            MLr     Hypo71               RSNC
# 44514      -77.415121            MLr
# 44811      -77.988167          MLr_1     Hypo71               RSNC
#
#            comment                                 Observations
# 3820          None           Incorrect magnitude type for zone1
# 5024                Event with comment different from DESTACADO
# 5699          None           Incorrect magnitude type for zone1
# 25336         None           Incorrect magnitude type for zone1
# 38253         None           Incorrect magnitude type for zone1
# 39295  DESTACADO\n  Event with comment different from DESTACADO
# 44199  DESTACADO\n  Event with comment different from DESTACADO
# 44514               Event with comment different from DESTACADO
# 7                4.819145                          49.0
# 8                7.821433                          19.0
# 9                     NaN                           NaN
# 10               5.504258                         140.0
# 11               2.899138                          22.0
# 12               1.909188                          18.0
# 13               3.083073                          72.0
# 14               2.333452                          69.0
# 15               2.468013                         120.0
# 16               9.399577                          27.0
# 17               9.876757                          23.0
# 18                    NaN                           NaN
# 19              10.535891                           7.0
# 20               4.916613                          27.0
# 21                    NaN                          13.0
# 22               1.484924                          18.0
#
#     quality_usedPhaseCount  ...                   event_type  \
# 0                     14.0  ...                   earthquake
# 1                     11.0  ...                   earthquake
# 2                     19.0  ...                   earthquake
# 3                     57.0  ...  outside of network interest
# 4                     14.0  ...                   earthquake
# 5                      7.0  ...                    explosion
# 6                     13.0  ...                    explosion
# 7                     45.0  ...                   earthquake
# 8                     19.0  ...                   earthquake
# 9                      NaN  ...  outside of network interest
# 10                   125.0  ...  outside of network interest
# 11                    20.0  ...                   earthquake
# 12                    10.0  ...                   earthquake
# 13                    71.0  ...                   earthquake
# 14                    68.0  ...                   earthquake
# 15                   117.0  ...                   earthquake
# 16                    24.0  ...                   earthquake
# 17                    23.0  ...                   earthquake
# 18                    24.0  ...            volcanic eruption
# 19                     7.0  ...                   earthquake
# 20                    18.0  ...                   earthquake
# 21                    13.0  ...                   earthquake
# 22                    18.0  ...                   earthquake
#
#     creationInfo_agencyID                                               text  \
# 0                     SGC                       Onzaga - Santander, Colombia
# 1                     SGC      San Vicente de ChucurÃ­ - Santander, Colombia
# 2                     SGC                                    Océano Pacífico
# 3                    USGS                                      Puerto, Chile
# 4                     SGC                     Colombia-Ecuador Border Region
# 5                     SGC              La Jagua de Ibirico - Cesar, Colombia
# 6                     SGC                        Becerrill - Cesar, Colombia
# 7                     SGC                   Los Santos - Santander, Colombia
# 8                     SGC           Arboledas - Norte de Santander, Colombia
# 9                    USGS                                  Oistins, Barbados
# 10                    SGC                                   Windward Islands
# 11                    SGC                                    Océano Pacífico
# 12                    SGC  El Litoral del San Juán (Docordó) - Chocó, Col...
# 13                    SGC  El Litoral del San Juán (Docordó) - Chocó, Col...
# 14                    SGC                                    Océano Pacífico
# 15                    SGC                          Istmina - Chocó, Colombia
# 16                    SGC                             Sipí - Chocó, Colombia
# 17                    SGC                     Marsella - Risaralda, Colombia
# 18                 OVSPOP  Totoró - Cauca, Colombia - Área de Influencia ...
# 19                    SGC                      San Agustín - Huila, Colombia
# 20                    SGC                         El Tambo - Cauca, Colombia
# 21                   OVSP              Área de Influencia del Volcán Galeras
# 22                    SGC              Panamá - Colombia , Región Fronteriza
#
#    latitude_value longitude_value magnitude_type   methodID  \
# 0        6.221167      -72.782667          MLr_3     Hypo71
# 1        6.739833      -73.395000        MLr_vmm     Hypo71
# 2        2.555333      -79.800333          MLr_1     Hypo71
# 3      -20.032900      -70.950000            mwr
# 4        0.793667      -77.929500          MLr_1     Hypo71
# 5        9.643167      -73.413000          MLr_4     Hypo71
# 6        9.684000      -73.341333          MLr_4     Hypo71
# 7        6.791371      -73.110256          MLr_3  NonLinLoc
# 8        7.534811      -72.944324          MLr_3  NonLinLoc
# 9       11.900000      -59.100000             mb
# 10      12.124347      -59.531719        Mw(Mwp)     LOCSAT
# 11       5.852167      -78.327667          MLr_1     Hypo71
# 12       4.144667      -76.788333          MLr_1     Hypo71
# 13       4.120063      -76.769755          MLr_1  NonLinLoc
# 14       3.054667      -79.252167          MLr_1     Hypo71
# 15       4.464816      -76.705386          MLr_1  NonLinLoc
# 16       4.698529      -76.328161          MLr_1  NonLinLoc
# 17       4.924839      -75.764090          MLr_2  NonLinLoc
# 18       2.399000      -76.337333            MLr     Hypo71
# 19       2.100167      -76.529333          MLr_2     Hypo71
# 20       2.430138      -76.888878          MLr_1  NonLinLoc
# 21       1.290207      -77.415121            MLr
# 22       7.527167      -77.988167          MLr_1     Hypo71
#
#          earthModelID      comment  \
# 0                RSNC         None
# 1                 VMM         None
# 2                RSNC         None
# 3
# 4                RSNC         None
# 5         modelCesar2         None
# 6         modelCesar2         None
# 7   Poveda_et_al_2018         None
# 8   Poveda_et_al_2018         None
# 9                             None
# 10             iasp91         None
# 11               RSNC         None
# 12               RSNC         None
# 13  Poveda_et_al_2018         None
# 14               RSNC         None
# 15  Poveda_et_al_2018  DESTACADO\n
# 16  Poveda_et_al_2018         None
# 17  Poveda_et_al_2018         None
# 18               RSNC  DESTACADO\n
# 19               RSNC         None
# 20  Poveda_et_al_2018         None
# 21
# 22               RSNC         None
#
#                                         Observations
# 0    SSWA: Possible duplicate event of SGC2026evfjyn
# 1    SSWA: Possible duplicate event of SGC2026evfjqe
# 2                 Incorrect magnitude type for zone1
# 3        Event with comment different from DESTACADO
# 4                 Incorrect magnitude type for zone1
# 5    SSWA: Possible duplicate event of SGC2026iyqgwu
# 6    SSWA: Possible duplicate event of SGC2026iyqgvw
# 7    SSWA: Possible duplicate event of SGC2026jaxfag
# 8    SSWA: Possible duplicate event of SGC2026jaxezo
# 9    SSWA: Possible duplicate event of SGC2026kpdwsu
# 10  SSWA: Possible duplicate event of USGS2026gcdsqo
# 11                Incorrect magnitude type for zone1
# 12   SSWA: Possible duplicate event of SGC2026psdocc
# 13   SSWA: Possible duplicate event of SGC2026psdoen
# 14                Incorrect magnitude type for zone1
# 15       Event with comment different from DESTACADO
# 16   SSWA: Possible duplicate event of SGC2026qputel
# 17   SSWA: Possible duplicate event of SGC2026qputsi
# 18       Event with comment different from DESTACADO
# 19   SSWA: Possible duplicate event of SGC2026rauaxl
# 20   SSWA: Possible duplicate event of SGC2026rauaxm
# 21       Event with comment different from DESTACADO
# 22                Incorrect magnitude type for zone1
#
# [23 rows x 23 columns]

# %%
# Print unique authors from the output
print(result.total_events['creationInfo_author'].unique())
# Out:
# ['william@proc3' 'kgarcia@proc2' 'scanlocbay' 'gerard@proc3'
#  'muruena@proc2' 'dcreina@proc3' 'axlopez@proc2' 'hmoreno@proc2'
#  'amarin@proc3' 'seismo@proc3' 'muruena@proc3' 'dcreina@proc2'
#  'william@proc2' 'kgarcia@proc3' 'axlopez@proc3' 'siscom' 'dperez@proc2'
#  'scanloc' 'amarin@proc2' 'gerard@proc2' 'homreno@proc3' 'sismologo'
#  'hmoreno@proc3' 'adagudelo@sismologo' 'LAKIY' 'automatic' 'dfruiz@proc2'
#  'scautoloc2@sc-principal' 'scanloc_b' 'scolv@sc-principal'
#  'scautoloc_reg']
